# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

Data = pd.read_csv("BeeData.csv")
hora = 8
minutos = 30
vetor = []
for i in range(0, 992):
  vetor.append(i)


Data = Data.assign(Hora=vetor)
x = Data["Hora"]
y = Data["Temperatura"]

Data
# Out:
#      Temperatura  Umidade Relativa do Ar %  ...  Numero de Luminuosidade  Hora
# 0             17                        83  ...                      496     0
# 1             17                        82  ...                      496     1
# 2             17                        83  ...                      498     2
# 3             17                        82  ...                      500     3
# 4             17                        83  ...                      499     4
# ..           ...                       ...  ...                      ...   ...
# 987           23                        59  ...                       99   987
# 988           23                        59  ...                       98   988
# 989           23                        59  ...                       98   989
# 990           23                        59  ...                       51   990
# 991           23                        59  ...                      100   991
#
# [992 rows x 5 columns]

# %%
sns.swarmplot("Hora",'Temperatura',  data=Data)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.swarmplot("Hora",'Numero de Luminuosidade',  data=Data)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.swarmplot("Hora",'Temperatura de Orvalho',  data=Data)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Nota-se que a medida que a luminuosidade diminui, maior o ruido entre os valores de luminuosidade

# %% [markdown]
# Variaveis que Gráficos seriam também interessantes:
# Variação do número de abelhas dentro da colmeia
# Variação do número de abelhas fora da colmeia
